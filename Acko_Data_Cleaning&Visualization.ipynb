# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("acko_cars.csv")

# %%
df
# Out:
#              Brand                                 Model  Body_Type  \
# 0          Hyundai                                 Creta        SUV
# 1          Hyundai                                 Venue        SUV
# 2              Kia                                 Sonet        SUV
# 3              Kia                                 Syros        SUV
# 4    Maruti Suzuki             Suzuki Baleno (2022-2025)  Hatchback
# ..             ...                                   ...        ...
# 293            Kia                       EV6 (2022-2025)        SUV
# 294            BYD                        e6 (2022-2024)        SUV
# 295           MINI                            Countryman        SUV
# 296           Audi                     RS Q8 (2020-2025)        SUV
# 297     Land Rover  Rover Range Rover Evoque (2024-2025)        SUV
#
#                    variant No.of Seats     Price Fuel_Type location  \
# 0                    1.5 E    5 Seater  ₹13.01 L    Petrol    Delhi
# 1                    1.2 E    5 Seater   ₹9.06 L    Petrol    Delhi
# 2               1.2 HTE(O)    5 Seater   ₹9.50 L    Petrol    Delhi
# 3            1.0 HTK Turbo    5 Seater  ₹10.60 L    Petrol    Delhi
# 4                1.2 Sigma    5 Seater   ₹7.58 L    Petrol    Delhi
# ..                     ...         ...       ...       ...      ...
# 293            GT Line AWD    5 Seater  ₹68.05 L  Electric    Delhi
# 294                     GL    5 Seater  ₹30.31 L  Electric    Delhi
# 295  Cooper S JCW Inspired    5 Seater  ₹54.73 L    Petrol    Delhi
# 296              4.0L TFSI    5 Seater  ₹2.51 Cr    Petrol    Delhi
# 297    SE R-Dynamic Diesel    5 Seater  ₹78.73 L    Diesel    Delhi
#
#     gearbox_Type
# 0         Manual
# 1         Manual
# 2         Manual
# 3         Manual
# 4         Manual
# ..           ...
# 293    Automatic
# 294    Automatic
# 295    Automatic
# 296    Automatic
# 297    Automatic
#
# [298 rows x 9 columns]

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ##### Previewing Data:
# ##### Using head() and tail() functions

# %%
df.head()
# Out:
#            Brand                      Model  Body_Type        variant  \
# 0        Hyundai                      Creta        SUV          1.5 E
# 1        Hyundai                      Venue        SUV          1.2 E
# 2            Kia                      Sonet        SUV     1.2 HTE(O)
# 3            Kia                      Syros        SUV  1.0 HTK Turbo
# 4  Maruti Suzuki  Suzuki Baleno (2022-2025)  Hatchback      1.2 Sigma
#
#   No.of Seats     Price Fuel_Type location gearbox_Type
# 0    5 Seater  ₹13.01 L    Petrol    Delhi       Manual
# 1    5 Seater   ₹9.06 L    Petrol    Delhi       Manual
# 2    5 Seater   ₹9.50 L    Petrol    Delhi       Manual
# 3    5 Seater  ₹10.60 L    Petrol    Delhi       Manual
# 4    5 Seater   ₹7.58 L    Petrol    Delhi       Manual

# %%
df.tail()
# Out:
#           Brand                                 Model Body_Type  \
# 293         Kia                       EV6 (2022-2025)       SUV
# 294         BYD                        e6 (2022-2024)       SUV
# 295        MINI                            Countryman       SUV
# 296        Audi                     RS Q8 (2020-2025)       SUV
# 297  Land Rover  Rover Range Rover Evoque (2024-2025)       SUV
#
#                    variant No.of Seats     Price Fuel_Type location  \
# 293            GT Line AWD    5 Seater  ₹68.05 L  Electric    Delhi
# 294                     GL    5 Seater  ₹30.31 L  Electric    Delhi
# 295  Cooper S JCW Inspired    5 Seater  ₹54.73 L    Petrol    Delhi
# 296              4.0L TFSI    5 Seater  ₹2.51 Cr    Petrol    Delhi
# 297    SE R-Dynamic Diesel    5 Seater  ₹78.73 L    Diesel    Delhi
#
#     gearbox_Type
# 293    Automatic
# 294    Automatic
# 295    Automatic
# 296    Automatic
# 297    Automatic

# %% [markdown]
# #### Structure of the data
# #### Using shape and ndim attributes

# %%
print("The shape of ----->" ,df.shape)
print("The No of Rows :" , df.shape[0])
print("The No of Columns :",df.shape[1])
# Out:
# The shape of -----> (298, 9)
# The No of Rows : 298
# The No of Columns : 9

# %%
print("The Dimension of the data Frame :",df.ndim)
# Out:
# The Dimension of the data Frame : 2

# %% [markdown]
# ### Check the random Samples of the Data

# %%
df.sample()
# Out:
#              Brand                       Model Body_Type variant No.of Seats  \
# 263  Maruti Suzuki  Suzuki S-Cross (2020-2022)       SUV   Delta    5 Seater
#
#         Price Fuel_Type location gearbox_Type
# 263  ₹11.76 L    Petrol    Delhi       Manual

# %% [markdown]
# ### Concise Summary:
# ##### info() : This is one of the most useful functions for a quick look at the data types, non-null values, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         298 non-null    object
#  1   Model         298 non-null    object
#  2   Body_Type     298 non-null    object
#  3   variant       298 non-null    object
#  4   No.of Seats   298 non-null    object
#  5   Price         298 non-null    object
#  6   Fuel_Type     298 non-null    object
#  7   location      298 non-null    object
#  8   gearbox_Type  298 non-null    object
# dtypes: object(9)
# memory usage: 21.1+ KB

# %% [markdown]
# #### Get basic descriptive statistics for numerical columns:
# #### This provides measures of central tendency, dispersion, and shape of the distribution.

# %%
df.describe(include = 'all')
# Out:
#                 Brand Model Body_Type variant No.of Seats     Price Fuel_Type  \
# count             298   298       298     298         298       298       298
# unique             35   297         8     255           7       279         4
# top     Mercedes-Benz   EQS       SUV     LXi    5 Seater  ₹1.70 Cr    Petrol
# freq               31     2       178       5         213         3       189
#
#        location gearbox_Type
# count       298          298
# unique        1            2
# top       Delhi    Automatic
# freq        298          197

# %% [markdown]
# ##### To find the name of all columns

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Body_Type', 'variant', 'No.of Seats', 'Price',
#        'Fuel_Type', 'location', 'gearbox_Type'],
#       dtype='object')

# %% [markdown]
# ##### To find the datatypes of columns

# %%
df.dtypes
# Out:
# Brand           object
# Model           object
# Body_Type       object
# variant         object
# No.of Seats     object
# Price           object
# Fuel_Type       object
# location        object
# gearbox_Type    object
# dtype: object

# %% [markdown]
# #### Missing Values Calculation

# %%
df.isnull().sum()
# Out:
# Brand           0
# Model           0
# Body_Type       0
# variant         0
# No.of Seats     0
# Price           0
# Fuel_Type       0
# location        0
# gearbox_Type    0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Standardizing Column names

# %%
df.columns = df.columns.str.title()
df.columns
# Out:
# Index(['Brand', 'Model', 'Body_Type', 'Variant', 'No.Of Seats', 'Price',
#        'Fuel_Type', 'Location', 'Gearbox_Type'],
#       dtype='object')

# %% [markdown]
# #### Change the column name and Standardizing Data Types
# The No.of Seats column's datatype is object. Converting the object datatypes into integer

# %%
df['No.Of Seats']
# Out:
# 0      5 Seater
# 1      5 Seater
# 2      5 Seater
# 3      5 Seater
# 4      5 Seater
#          ...
# 293    5 Seater
# 294    5 Seater
# 295    5 Seater
# 296    5 Seater
# 297    5 Seater
# Name: No.Of Seats, Length: 298, dtype: object

# %%
df['No.Of Seats'] = df['No.Of Seats'].str.split(' ').str[0]

# %%
df['No.Of Seats']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 293    5
# 294    5
# 295    5
# 296    5
# 297    5
# Name: No.Of Seats, Length: 298, dtype: object

# %%
df['No.Of Seats'] = df['No.Of Seats'].astype(int)

# %%
df.rename(columns = {'No.Of Seats' : 'Seater'},inplace = True)

# %%
df['Seater']
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 293    5
# 294    5
# 295    5
# 296    5
# 297    5
# Name: Seater, Length: 298, dtype: int32

# %% [markdown]
# #### Converting the Datatype of Price column into Float datatype
# Remove ₹ symbol and replacing "L" and "cr" and normalizing the data

# %%
df['Price']
# Out:
# 0      ₹13.01 L
# 1       ₹9.06 L
# 2       ₹9.50 L
# 3      ₹10.60 L
# 4       ₹7.58 L
#          ...
# 293    ₹68.05 L
# 294    ₹30.31 L
# 295    ₹54.73 L
# 296    ₹2.51 Cr
# 297    ₹78.73 L
# Name: Price, Length: 298, dtype: object

# %%
df['Price'] =df['Price'].str.replace("₹",'')

# %%
def convert_price(price_str):
    price_str = str(price_str).strip()
    if 'L' in price_str:
        return float(price_str.replace('L', '').strip()) * 1e5
    elif 'Cr' in price_str:
        return float(price_str.replace('Cr', '').strip()) * 1e7
    else:
       
        try:
            return float(price_str)
        except ValueError:
            return np.nan

# %%
df['Price'] = df['Price'].apply(convert_price)

# %%
df['Price'] = df['Price']/100000
df['Price']
# Out:
# 0       13.01
# 1        9.06
# 2        9.50
# 3       10.60
# 4        7.58
#         ...
# 293     68.05
# 294     30.31
# 295     54.73
# 296    251.00
# 297     78.73
# Name: Price, Length: 298, dtype: float64

# %%
df.dtypes
# Out:
# Brand            object
# Model            object
# Body_Type        object
# Variant          object
# Seater            int32
# Price           float64
# Fuel_Type        object
# Location         object
# Gearbox_Type     object
# dtype: object

# %% [markdown]
# #### Capitalizing the first letter of Brand name using title()

# %%
df['Brand'] = df['Brand'].str.title()
df['Brand']
# Out:
# 0            Hyundai
# 1            Hyundai
# 2                Kia
# 3                Kia
# 4      Maruti Suzuki
#            ...
# 293              Kia
# 294              Byd
# 295             Mini
# 296             Audi
# 297       Land Rover
# Name: Brand, Length: 298, dtype: object

# %% [markdown]
# #### Removing  year from model column

# %%
df['Model']
# Out:
# 0                                     Creta
# 1                                     Venue
# 2                                     Sonet
# 3                                     Syros
# 4                 Suzuki Baleno (2022-2025)
#                        ...
# 293                         EV6 (2022-2025)
# 294                          e6 (2022-2024)
# 295                              Countryman
# 296                       RS Q8 (2020-2025)
# 297    Rover Range Rover Evoque (2024-2025)
# Name: Model, Length: 298, dtype: object

# %% [markdown]
# ##### Using Regex extracting only model names from model column

# %%
import re
df['Model'] = df['Model'].str.replace(r'\s\(\d{4}-\d{4}\)','',regex=True)

# %%
df['Model']
# Out:
# 0                         Creta
# 1                         Venue
# 2                         Sonet
# 3                         Syros
# 4                 Suzuki Baleno
#                  ...
# 293                         EV6
# 294                          e6
# 295                  Countryman
# 296                       RS Q8
# 297    Rover Range Rover Evoque
# Name: Model, Length: 298, dtype: object

# %%
models = df['Model'].unique()
index = np.arange(1,len(models)+1)

# %%
pd.Series(models,index = index)
# Out:
# 1                  Creta
# 2                  Venue
# 3                  Sonet
# 4                  Syros
# 5          Suzuki Baleno
#              ...
# 247    Martin DB11Coupe4
# 248       M4 Competition
# 249                   e6
# 250           Countryman
# 251                RS Q8
# Length: 251, dtype: object

# %%
body_type = df['Body_Type'].unique()

# %%
pd.Series(body_type)
# Out:
# 0            SUV
# 1      Hatchback
# 2          Sedan
# 3        MPV/MUV
# 4    Minivan/Van
# 5          Coupe
# 6    Convertible
# 7        Pick-Up
# dtype: object

# %%
df['Variant']
# Out:
# 0                      1.5 E
# 1                      1.2 E
# 2                 1.2 HTE(O)
# 3              1.0 HTK Turbo
# 4                  1.2 Sigma
#                ...
# 293              GT Line AWD
# 294                       GL
# 295    Cooper S JCW Inspired
# 296                4.0L TFSI
# 297      SE R-Dynamic Diesel
# Name: Variant, Length: 298, dtype: object

# %%
df['Seater'].unique()
# Out:
# array([5, 7, 6, 8, 4, 2, 9])

# %%
Fuel_type = df['Fuel_Type'].unique()

# %%
pd.Series(Fuel_type)
# Out:
# 0      Petrol
# 1      Diesel
# 2    Electric
# 3         CNG
# dtype: object

# %%
Gear_type = df['Gearbox_Type'].unique()

# %%
pd.Series(Gear_type)
# Out:
# 0       Manual
# 1    Automatic
# dtype: object

# %%
df
# Out:
#              Brand                     Model  Body_Type  \
# 0          Hyundai                     Creta        SUV
# 1          Hyundai                     Venue        SUV
# 2              Kia                     Sonet        SUV
# 3              Kia                     Syros        SUV
# 4    Maruti Suzuki             Suzuki Baleno  Hatchback
# ..             ...                       ...        ...
# 293            Kia                       EV6        SUV
# 294            Byd                        e6        SUV
# 295           Mini                Countryman        SUV
# 296           Audi                     RS Q8        SUV
# 297     Land Rover  Rover Range Rover Evoque        SUV
#
#                    Variant  Seater   Price Fuel_Type Location Gearbox_Type
# 0                    1.5 E       5   13.01    Petrol    Delhi       Manual
# 1                    1.2 E       5    9.06    Petrol    Delhi       Manual
# 2               1.2 HTE(O)       5    9.50    Petrol    Delhi       Manual
# 3            1.0 HTK Turbo       5   10.60    Petrol    Delhi       Manual
# 4                1.2 Sigma       5    7.58    Petrol    Delhi       Manual
# ..                     ...     ...     ...       ...      ...          ...
# 293            GT Line AWD       5   68.05  Electric    Delhi    Automatic
# 294                     GL       5   30.31  Electric    Delhi    Automatic
# 295  Cooper S JCW Inspired       5   54.73    Petrol    Delhi    Automatic
# 296              4.0L TFSI       5  251.00    Petrol    Delhi    Automatic
# 297    SE R-Dynamic Diesel       5   78.73    Diesel    Delhi    Automatic
#
# [298 rows x 9 columns]

# %%
df.to_csv("acko_cleaned_cars.csv",index=False)

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Categorial Columns Analysis
# Gearbox_Type Distribution.
# Chart Type: Bar Chart.
# Purpose: To compare the number of cars with manual versus automatic transmissions.
# Insights: This chart would quickly reveal the preference for a specific type of transmission among the cars in the dataset.

# %% [markdown]
# # Gear Box Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(4, 5))
ax= sns.countplot(x='Gearbox_Type', data=df, palette='muted')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
               textcoords='offset points')
plt.title("Gearbox Type Distribution")
plt.xlabel("Gearbox")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### Fuel_Type Distribution
# Chart Type:  Bar Chart
# Purpose: To display the proportion of each fuel type (Petrol, Diesel, Electric, CNG).
# Insights: This will enable us find the distribution of cars over fuel types

# %%
plt.figure(figsize=(6, 4))
Fuel = sns.countplot(x='Fuel_Type', data=df, order=df['Fuel_Type'].value_counts().index, palette='Set1')
for p in Fuel.patches:
    Fuel.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
               textcoords='offset points')
plt.title("Fuel Type Count")
plt.xlabel("Count")
plt.ylabel("Fuel Type")
plt.show()

# %% [markdown]
# #### Brand Distribution
# Chart Type: Bar Chart
# Purpose: To identify the top car brands listed.
# Insights: This visualization would show which brands (e.g., Maruti Suzuki, Hyundai, Tata) have the most models available in the Acko dataset,    highlighting key partnerships or inventory focus.

# %%
top_brands = df['Brand'].value_counts().head(10)
plt.figure(figsize=(12, 5))
bx = sns.barplot(x=top_brands.index, y=top_brands.values, palette='coolwarm')
for p in bx.patches:
    bx.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
               textcoords='offset points')
plt.title("Top 10 Brands")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### Body_Type Distribution
# Chart Type: Bar Chart
# Purpose: To show the frequency of each car body type in the dataset.
# Insights: This visualization would clearly show which body types (e.g., SUV, Hatchback, Sedan) are most common in the Acko car listings, providing an   overview of the most popular segments.

# %%
plt.figure(figsize=(10, 5))
Body_Type = df['Body_Type'].value_counts()
bt = sns.barplot(x=Body_Type.index, y=Body_Type.values, palette='viridis')
for p in bt.patches:
    bt.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
               textcoords='offset points')
plt.title('Distribution of Body Types', fontsize=16)
plt.xlabel('Body Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Numerical Columns

# %%
plt.figure(figsize=(8, 4))
st = sns.countplot(x='Seater', data=df, palette='Set2')
for p in st.patches:
    st.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
               ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
               textcoords='offset points')
plt.title("Distribution of Seaters")
plt.xlabel("Seaters")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], kde=True, bins=20)
plt.title("Distribution of the Price column")
# Out:
# Text(0.5, 1.0, 'Distribution of the Price column')

# %% [markdown]
# ### Box Plot analysis of price column

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['Price'])
plt.title('Box Plot of Car Prices')
plt.xlabel('Price (in Lakhs)')
plt.tight_layout()
plt.show()
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1
print(f"First Quartile (Q1): {Q1:.2f}")
print(f"Third Quartile (Q3): {Q3:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
# Out:
# First Quartile (Q1): 13.49
# Third Quartile (Q3): 119.50
# Interquartile Range (IQR): 106.01

# %%
df.dtypes

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Fuel_Type', y='Price', palette='Set2',legend=False)
plt.title('Boxplot: Price by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Price (₹)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
crosstab = pd.crosstab(df['Fuel_Type'], df['Gearbox_Type'])
plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap='Blues', fmt='d')
plt.title('Heatmap: Fuel Type vs Transmission')
plt.xlabel('Transmission')
plt.ylabel('Fuel Type')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Body_Type', y='Price', data=df)
plt.title('Price Distribution by Body Type')
plt.xlabel('Body Type')
plt.ylabel('Price (in Lakhs)')
plt.show()
